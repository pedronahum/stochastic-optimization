# %% [markdown]
# # Medical Decision Making - Diabetes
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pedronahum/stochastic-optimization/blob/master/notebooks/medical_decision_diabetes.ipynb)

# %%
# Setup (Google Colab): clone the repo and install it with all dependencies.
import os, shutil, sys

if os.path.exists('stochastic-optimization'):
    shutil.rmtree('stochastic-optimization')
# !git clone -q https://github.com/pedronahum/stochastic-optimization.git
os.chdir('stochastic-optimization')
# Installs jax, flax, optax, chex, jaxtyping, ott-jax, scipy (+ matplotlib and
# networkx via the viz extra) from pyproject, so the notebook always matches
# the package's real dependencies.
# !pip install -q -e ".[viz]"

# Drop any half-imported modules so the freshly installed package is used.
for _m in [m for m in list(sys.modules) if m.startswith(('problems', 'core'))]:
    del sys.modules[_m]
print('\u2713 Setup complete!')

# %%
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import numpy as np

# Import problem components
from problems.medical_decision_diabetes import (
    MedicalDecisionDiabetesConfig,
    MedicalDecisionDiabetesModel,
    UCBPolicy,
    ThompsonSamplingPolicy,
)

print('✓ Imports successful')
print(f'JAX version: {jax.__version__}')
print(f'JAX backend: {jax.default_backend()}')

# %%
# Create model configuration (5-drug effectiveness bandit)
config = MedicalDecisionDiabetesConfig(
    n_drugs=5,
    initial_mu=0.5,
    measurement_sigma=0.05,
)
model = MedicalDecisionDiabetesModel(config)

# UCB explores drugs by upper confidence bound
policy = UCBPolicy(theta=2.0)

key = jax.random.PRNGKey(0)
state = model.init_state(key)
print('✓ Model and policy ready')

# %%
# Sequentially choose drugs with UCB and track which drug is selected and
# the realised effectiveness reward.
import numpy as np
chosen_drugs, rewards = [], []
for t in range(48):
    key, k = jax.random.split(key)
    decision = policy(None, state, k, time=t + 1)     # drug index (0-4)
    exog = model.sample_exogenous(k, state, t, decision=int(decision))
    rewards.append(float(model.reward(state, decision, exog)))
    chosen_drugs.append(int(decision))
    state = model.transition(state, decision, exog)

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(chosen_drugs, 'o-', ms=3); plt.title('Drug selected over time')
plt.yticks(range(config.n_drugs)); plt.ylabel('drug index')
plt.subplot(1, 2, 2)
plt.plot(np.cumsum(rewards)); plt.title('Cumulative effectiveness')
plt.tight_layout(); plt.show()
best = int(np.bincount(chosen_drugs).argmax())
print(f'Most-selected drug: {best}')

# %% [markdown]
# ## References
#
# 1. **Sequential Decision Analytics Lab** - https://castle.princeton.edu/sdalinks/
# 2. **Repository** - https://github.com/pedronahum/stochastic-optimization
# 3. **JAX Documentation** - https://jax.readthedocs.io/
