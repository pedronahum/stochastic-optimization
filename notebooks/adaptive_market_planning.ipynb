# %% [markdown]
# # Adaptive Market Planning
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pedronahum/stochastic-optimization/blob/master/notebooks/adaptive_market_planning.ipynb)

# %%
# Setup (Google Colab): clone the repo and install it with all dependencies.
import os, shutil, sys

if os.path.exists('stochastic-optimization'):
    shutil.rmtree('stochastic-optimization')
# !git clone -q https://github.com/pedronahum/stochastic-optimization.git
os.chdir('stochastic-optimization')
# Installs jax, flax, optax, chex, jaxtyping, ott-jax, scipy (+ matplotlib and
# networkx via the viz extra) from pyproject, so the notebook always matches
# the package's real dependencies.
# !pip install -q -e ".[viz]"

# Drop any half-imported modules so the freshly installed package is used.
for _m in [m for m in list(sys.modules) if m.startswith(('problems', 'core'))]:
    del sys.modules[_m]
print('\u2713 Setup complete!')

# %%
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import numpy as np

# Import problem components
from problems.adaptive_market_planning import (
    AdaptiveMarketPlanningConfig,
    AdaptiveMarketPlanningModel,
    HarmonicStepPolicy,
    KestenStepPolicy,
)

print('✓ Imports successful')
print(f'JAX version: {jax.__version__}')
print(f'JAX backend: {jax.default_backend()}')

# %%
# Create model configuration
config = AdaptiveMarketPlanningConfig(
    price=1.5,
    cost=0.8,
    demand_mean=100.0,
    initial_order_quantity=50.0,
)
model = AdaptiveMarketPlanningModel(config)

# Harmonic (1/n) step-size rule for the stochastic-gradient learner
policy = HarmonicStepPolicy(theta=1.0)

key = jax.random.PRNGKey(0)
state = model.init_state(key)
print('✓ Model and policy ready')

# %%
# Learn the order quantity via stochastic gradient ascent on profit.
# It should converge to the newsvendor optimum q* = demand_mean * ln(price/cost).
import numpy as np
order_quantities, rewards = [], []
for t in range(200):
    key, k = jax.random.split(key)
    policy.current_time = t + 1            # harmonic step uses internal time
    decision = policy(None, state, k)       # step_size
    exog = model.sample_exogenous(k, state, t)
    rewards.append(float(model.reward(state, decision, exog)))
    order_quantities.append(float(state[0]))
    state = model.transition(state, decision, exog)

q_opt = config.demand_mean * np.log(config.price / config.cost)
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(order_quantities, label='learned q')
plt.axhline(q_opt, color='r', ls='--', label=f'newsvendor q*={q_opt:.1f}')
plt.title('Order quantity'); plt.legend()
plt.subplot(1, 2, 2)
plt.plot(np.cumsum(rewards)); plt.title('Cumulative profit')
plt.tight_layout(); plt.show()
print(f'Final order quantity: {order_quantities[-1]:.2f}  (optimal {q_opt:.2f})')

# %% [markdown]
# ## References
#
# 1. **Sequential Decision Analytics Lab** - https://castle.princeton.edu/sdalinks/
# 2. **Repository** - https://github.com/pedronahum/stochastic-optimization
# 3. **JAX Documentation** - https://jax.readthedocs.io/
